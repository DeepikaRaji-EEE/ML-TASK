# %%
import pandas as pd
import statsmodels.api as sm

from statsmodels.discrete.count_model import ZeroInflatedPoisson


df = pd.read_csv("/content/ndtv_data_final.csv")
df
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
X = df[["Brand","Model"]]
X
# Out:
#          Brand                   Model
# 0      OnePlus  7T Pro McLaren Edition
# 1       Realme                  X2 Pro
# 2        Apple       iPhone 11 Pro Max
# 3        Apple               iPhone 11
# 4           LG               G8X ThinQ
# ...        ...                     ...
# 1354     Intex                 Aqua A2
# 1355  Videocon      Infinium Z51 Nova+
# 1356     Intex                 Aqua Y4
# 1357     iBall               Andi4 B20
# 1358     iBall           Andi Avonte 5
#
# [1359 rows x 2 columns]

# %%
y = df["Processor"]
y
# Out:
# 0       8
# 1       8
# 2       6
# 3       6
# 4       8
#        ..
# 1354    4
# 1355    4
# 1356    2
# 1357    1
# 1358    4
# Name: Processor, Length: 1359, dtype: int64

# %%
X = sm.add_constant(X)
X
# Out:
#       const     Brand                   Model
# 0       1.0   OnePlus  7T Pro McLaren Edition
# 1       1.0    Realme                  X2 Pro
# 2       1.0     Apple       iPhone 11 Pro Max
# 3       1.0     Apple               iPhone 11
# 4       1.0        LG               G8X ThinQ
# ...     ...       ...                     ...
# 1354    1.0     Intex                 Aqua A2
# 1355    1.0  Videocon      Infinium Z51 Nova+
# 1356    1.0     Intex                 Aqua Y4
# 1357    1.0     iBall               Andi4 B20
# 1358    1.0     iBall           Andi Avonte 5
#
# [1359 rows x 3 columns]

# %%
print(X.select_dtypes(include="object").columns)
# Out:
# Index(['Brand', 'Model'], dtype='object')

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
print(df["Processor"].value_counts())
# Out:
# Processor
# 4     683
# 8     565
# 2      45
# 1      42
# 6      20
# 10      4
# Name: count, dtype: int64

# %%
zero_percentage = (df["Processor"] == 0).mean() * 100

print("Zero Percentage:", round(zero_percentage,2), "%")
# Out:
# Zero Percentage: 0.0 %

# %%
age = int(input("Enter Brand: "))
bmi = float(input("Enter Model: "))

new_data = pd.DataFrame({
    "const": [1],
    "Model": [Model],
    "Brand": [Brand]
})

prediction = result.predict(
    exog=new_data,
    exog_infl=new_data
)

print("Predicted Children:", round(prediction[0]))
